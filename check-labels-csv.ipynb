# %%
import pandas as pd

# %%
df = pd.read_csv('./data-train-download/label.csv')

# %%
x = df['label'].value_counts()[0:400]
for i in range(400):
    print(x.index[i], x[i])

new_df = df[df['label'].isin(x.index[0:2])]
new_df.to_csv('./data-train-download/label_2.csv', index=False)
# Out:
# tango dancing 283
# playing paintball 276
# singing 275
# spinning poi 270
# salsa dancing 269
# playing ukulele 269
# ice skating 269
# squat 267
# capoeira 266
# feeding birds 266
# contact juggling 266
# cheerleading 266
# crawling baby 265
# archery 265
# playing bass guitar 264
# arm wrestling 264
# walking the dog 264
# marching 263
# blowing out candles 262
# punching bag 261
# biking through snow 261
# skiing (not slalom or crosscountry) 260
# playing violin 260
# dunking basketball 259
# eating spaghetti 259
# hitting baseball 258
# blowing glass 258
# jetskiing 258
# playing trombone 257
# air drumming 256
# mowing lawn 256
# playing poker 256
# snowkiting 256
# playing recorder 256
# riding or walking with horse 256
# presenting weather forecast 256
# skateboarding 255
# abseiling 251
# diving cliff 251
# hula hooping 251
# dancing ballet 250
# passing American football (not in game) 249
# playing basketball 249
# playing tennis 249
# playing harmonica 249
# ...

# %%
df.shape
# Out:
# (62605, 2)
